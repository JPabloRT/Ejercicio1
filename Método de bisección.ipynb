# %%
import matplotlib.pyplot as plt
def biseccion():
  print("Metodo de la biseccion")
  print("Suponiendo nuestra funcion sea x al cubo + 4x cuadrada -10")
  print("Siendo los intervalos [1,2]")
  x1=1
  xu=2
  fx1 = (x1**3)+(4*(x1**2)-10)
  fxu = (xu ** 3) + (4 * (xu ** 2) - 10)
  xrgrafico=[]
  if(fxu * fx1 < 0):
    xr=(x1 + xu) / 2
  fxr=(xr ** 3) + (4 * (xr **2 ) - 10)

  xrgrafico.append(xr)
  print(xr)
  er= 1 
  while er> 0.001:
    if(fxu*fxr<0):
      x1=xr
      fx1=(x1 ** 3) + (4 ** (x1 ** 2) - 10)
      fxu= (xu *+ 3) + (4 * (xu ** 2) - 10)
      xr= ( x1 + xu )/2
      fxr=(xr **3 ) + (4 * (xr ** 2)- 10)
      er=(xr-xl)/xr 
      xrgrafico.append(xr)
      print(xr)
      if(fx1 * fxr <0):
        xu=xr
        fx1=(x1 ** 3)+ (4 * (x1 ** 2)-10)
        fxu=(xu ** 3) + (4* (xu **2)-10)
        xr = (x1 + xu)/2
        fxr=(xr ** 3) + (4* (xr ** 2)-10)
        er=(xr -x1)/ xr
        xrgrafico.append(xr)
        print(xr)
        if(fxu*fxr>0 and fx1*fxr>0):
          print("No tiene raiz, fin del programa")


lxr = list()
def biseccion():
    print("Metodo de la biseccion")
    print("Suponiendo nuestra funcion sea x al cubo + 4x cuadrada - 10")
    print("Sindo los intervalos [1,2]")
    xl=1
    xu=2
    fxl=(xl**3)+(4*(xl**2)-10)
    fxu = (xu ** 3) + (4 * (xu ** 2) - 10)
    if(fxu*fxl<0):
        xr=(xl+xu)/2
        fxr = (xr ** 3) + (4 * (xr ** 2) - 10)
        print(xr)
        lxr.append(xr)
        er = 1
        while er > 0.001:
            if(fxu*fxr<0):
                xl=xr
                fxl = (xl ** 3) + (4 * (xl ** 2) - 10)
                fxu = (xu ** 3) + (4 * (xu ** 2) - 10)
                xr = (xl + xu) / 2
                fxr = (xr ** 3) + (4 * (xr ** 2) - 10)
                er=(xr-xl)/xr
                print(xr)
                lxr.append(xr)
            if (fxl * fxr < 0):
                xu=xr
                fxl = (xl ** 3) + (4 * (xl ** 2) - 10)
                fxu = (xu ** 3) + (4 * (xu ** 2) - 10)
                xr = (xl + xu) / 2
                fxr = (xr ** 3) + (4 * (xr ** 2) - 10)
                er = (xr - xl) / xr
                print(xr)
                lxr.append(xr)
            if (fxu*fxr>0 and fxl*fxr>0):
                print("No tiene raiz, fin del programa")
    else:
        print("No tiene raiz, fin del programa")

biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# Metodo de la biseccion
# Suponiendo nuestra funcion sea x al cubo + 4x cuadrada - 10
# Sindo los intervalos [1,2]
# 1.5
# 1.25
# 1.375
# 1.3125
# 1.34375
# 1.359375
# 1.3671875
# 1.36328125
# 1.365234375
# 1.3642578125
